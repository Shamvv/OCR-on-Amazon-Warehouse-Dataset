# %%
# !pip install paddlepaddle-gpu==2.6.2 paddleocr
# Out:
# Requirement already satisfied: paddlepaddle-gpu==2.6.2 in /usr/local/lib/python3.10/dist-packages (2.6.2)
# Requirement already satisfied: paddleocr in /usr/local/lib/python3.10/dist-packages (2.8.1)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu==2.6.2) (0.27.2)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu==2.6.2) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu==2.6.2) (9.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu==2.6.2) (4.4.2)
# Requirement already satisfied: astor in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu==2.6.2) (0.8.1)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu==2.6.2) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu==2.6.2) (3.20.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.23.2)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (from paddleocr) (1.3.0.post5)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.10/dist-packages (from paddleocr) (1.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.66.5)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from paddleocr) (3.9.7)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (from paddleocr) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.53.1)
# Requirement already satisfied: fire>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu==2.6.2) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu==2.6.2) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu==2.6.2) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu==2.6.2) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu==2.6.2) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->paddlepaddle-gpu==2.6.2) (0.14.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (3.7.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (2.34.2)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (3.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (2.0.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle-gpu==2.6.2) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (2.8.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from paddleocr import PaddleOCR, draw_ocr
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en')  # Use English model
# Out:
# [2024/09/15 08:42:31] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %% [markdown]
# #HANDLE VARIABLE `n` IN THE FOLLOWING BLOCK WITH EXTREME CARE!!!!! IT SETS HOW MANY IMAGES YOU WILL DOWNLOAD AND TEST!!!

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv("test.csv")

# Select rows from index 17975 to 34999 (since Python indexing is zero-based)
df1 = df.iloc[35000:60000]

# Extract relevant columns into lists from the sliced dataframe
list_of_image_paths = df1['image_link'].to_list()
e_name = df1['entity_name'].to_list()
index = df1['index'].to_list()
g_id = df1['group_id'].to_list()

# number of input images (from the sliced dataset)
n = len(list_of_image_paths)

# Now you can proceed with further analysis on the sliced data

# %%
import requests
for i in range(n):

  # Image URL
  url = list_of_image_paths[i]

  # Send GET request
  response = requests.get(url)
  img_path = 'image'+str(i)+'.jpg'
  # Save the image to a file
  if response.status_code == 200:
      with open(img_path, 'wb') as file:
          file.write(response.content)
  else:
      print("Failed to retrieve image.")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467             try:
# --> 468                 self._validate_conn(conn)
#     469             except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1096         if conn.is_closed:
# -> 1097             conn.connect()
#    1098
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     641
# --> 642         sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643             sock=sock,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     782
# --> 783     ssl_sock = ssl_wrap_socket(
#     784         sock=sock,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     470
# --> 471     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     472     return ssl_sock
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     514
# --> 515     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# /usr/lib/python3.10/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     512         # ctx._wrap_socket()
# --> 513         return self.sslsocket_class._create(
#     514             sock=sock,
#
# /usr/lib/python3.10/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1099                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1100                     self.do_handshake()
#    1101             except (OSError, ValueError):
#
# /usr/lib/python3.10/ssl.py in do_handshake(self, block)
#    1370                 self.settimeout(None)
# -> 1371             self._sslobj.do_handshake()
#    1372         finally:
#
# SSLError: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     491                 new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 492             raise new_e
#     493
#
# SSLError: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     844
# --> 845             retries = retries.increment(
#     846                 method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     514             reason = error or ResponseError(cause)
# --> 515             raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     516
#
# MaxRetryError: HTTPSConnectionPool(host='m.media-amazon.com', port=443): Max retries exceeded with url: /images/I/41wmVvL3kUS.jpg (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-7-1b1769176aaf> in <cell line: 2>()
#       6
#       7   # Send GET request
# ----> 8   response = requests.get(url)
#       9   img_path = 'image'+str(i)+'.jpg'
#      10   # Save the image to a file
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     696             if isinstance(e.reason, _SSLError):
#     697                 # This branch is for urllib3 v1.22 and later.
# --> 698                 raise SSLError(e, request=request)
#     699
#     700             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='m.media-amazon.com', port=443): Max retries exceeded with url: /images/I/41wmVvL3kUS.jpg (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007)')))

# %%
import os

# Directory where images are saved (in Colab)
image_dir = '/content/'

# List all files in the directory that match the pattern "image*.jpg"
image_files = [f for f in os.listdir(image_dir) if f.startswith('image') and f.endswith('.jpg')]

# Extract the numbers from the filenames and convert them to integers
image_numbers = [int(f.replace('image', '').replace('.jpg', '')) for f in image_files]

# Find the maximum number
if image_numbers:
    max_downloaded = max(image_numbers)
    print(f"The highest image number downloaded is: {max_downloaded}")

    # Check if all images from 0 to max_downloaded are present
    missing_images = [i for i in range(max_downloaded + 1) if i not in image_numbers]

    if not missing_images:
        print(f"All images from 0 to {max_downloaded} are downloaded in sequence.")
    else:
        print(f"Missing images: {missing_images}")
else:
    print("No images found.")
# Out:
# The highest image number downloaded is: 17974
# All images from 0 to 17974 are downloaded in sequence.

# %%
def extract_text_from_image(image_path):
    # Perform OCR on the image
    result = ocr.ocr(image_path, cls=True)
    temp = []
    if result[0] is None:
      return "Not Found"
    for i in range(len(result[0])):
      temp.append(result[0][i][-1][0])
    return "".join(temp)

# %%
import re

# Define regex patterns for different elements with updated unit lists
patterns = {
    "item_weight": r"(\d+(\.\d+)?)(\s?(mg|g|kg|lb|lbs|pounds|oz|ounce|ounces|ton|microgram))",
    "item_volume": r"(\d+(\.\d+)?)(\s?(ml|l|liters?|fl oz|fluid ounce|milliliter|liter|ounce|cubic foot|microlitre|cup|centilitre|imperial gallon|pint|decilitre|quart|cubic inch|gallon))",
    "height": r"(\d+(\.\d+)?)(\s?(cm|m|in|inch|inches|feet|ft|centimeter|meter|foot|\"|mm|millimetre|yard))",
    "depth": r"(\d+(\.\d+)?)(\s?(cm|m|in|inch|inches|feet|ft|centimeter|meter|foot|\"|mm|millimetre|yard))",
    "width": r"(\d+(\.\d+)?)(\s?(cm|m|in|inch|inches|feet|ft|centimeter|meter|foot|\"|mm|millimetre|yard))",
    "voltage": r"(\d+(\.\d+)?)(\s?(V|volts?|kilovolt|millivolt))",
    "wattage": r"(\d+(\.\d+)?)(\s?(W|watts?|kilowatt))",
}

# Map abbreviations to full forms
unit_mappings = {
    "mg": "milligram",
    "g": "gram",
    "kg": "kilogram",
    "lb": "pound",
    "lbs": "pound",
    "pounds": "pound",
    "oz": "ounce",
    "ounce": "ounce",
    "ounces": "ounce",
    "ml": "millilitre",
    "l": "liter",
    "liters": "liter",
    "fl oz": "fluid ounce",
    "fl": "fluid ounce",
    " fl": "fluid ounce",
    "cm": "centimetre",
    "m": "meter",
    "in": "inch",
    "inch": "inch",
    "inches": "inch",
    "ft": "foot",
    "feet": "foot",
    "mm": "millimetre",
    "millimetre": "millimetre",
    "yard": "yard",
    " cm": "centimetre",
    " m": "metre",
    " in": "inch",
    "inch": "inch",
    "inches": "inch",
    "ft": "foot",
    "feet": "foot",
    " mm": "millimetre",
    "mm": "millimetre",
    "millimetre": "millimetre",
    "yard": "yard",
    "V": "volt",
    "v": "volt",
    " v": "volt",
    " V": "volt",
    "volts": "volt",
    "W": "watt",
    "w": "watt",
    " W": "watt",
    " w": "watt",
    "V": "volt",
    "volts": "volt",
    "W": "watt",
    " w": "watt",
    " W": "watt",
    "w": "watt",
    "watts": "watt",
    "kilovolt": "kilovolt",
    "millivolt": "millivolt",
    "kilowatt": "kilowatt",
    "ton": "ton",
    "microgram": "microgram",
    "cubic foot": "cubic foot",
    "microlitre": "microlitre",
    "cup": "cup",
    "centilitre": "centilitre",
    "imperial gallon": "imperial gallon",
    "pint": "pint",
    "decilitre": "decilitre",
    "quart": "quart",
    "cubic inch": "cubic inch",
    "gallon": "gallon",
    ' "' : "inch",
    '"': "inch"
}

# Unit conversion to grams for weights
unit_conversion = {
    "mg": 0.001,
    "g": 1,
    "kg": 1000,
    "lb": 453.592,
    "lbs": 453.592,
    "pounds": 453.592,
    "oz": 28.3495,
    "ounce": 28.3495,
    "ounces": 28.3495,
    "ton": 1000000,
    "microgram": 0.000001
}

def format_decimal(value):
    """Ensure the number has one decimal place only if it doesn't already have decimals."""
    if "." not in value:
        return f"{value}.0"
    return value

def replace_units_with_full_form(match):
    """Helper function to replace abbreviations with full-form units."""
    value = match[0]  # Access the value part of the tuple
    unit = match[3].lower()  # Access the unit part for the element

    # Replace unit with its full form using the mapping
    full_unit = unit_mappings.get(unit, unit)

    # For height, width, depth, weight, and voltage, ensure the value has one decimal
    if full_unit in ["centimetre", "meter", "inch", "foot", "gram", "kilogram", "ounce", "volt"]:
        value = format_decimal(value)

    return f"{value} {full_unit}"

def find_highest_weight(matches):
    """
    Helper function to find the highest weight in the list of matches.
    If both grams and ounces are present, ounces are preferred.
    """
    max_weight = 0
    result = ""
    found_ounce = None

    for match in matches:
        try:
            weight = float(match[0])  # The numeric value
            unit = match[3].lower()   # The unit, like mg, g, kg, etc.

            # If ounce is found, prefer it over grams
            if unit in ["oz", "ounce", "ounces"]:
                found_ounce = match  # Store ounce value, continue to find if there's any larger weight
            weight_in_grams = weight * unit_conversion[unit]  # Convert to grams

            if weight_in_grams > max_weight:
                max_weight = weight_in_grams
                result = replace_units_with_full_form(match)
        except ValueError:
            continue  # Skip if there's an error converting the weight

    # If ounce was found, prefer it
    if found_ounce:
        result = replace_units_with_full_form(found_ounce)

    return result

def sort_matches_by_value(matches):
    """Helper function to sort matches by numeric value."""
    return sorted(matches, key=lambda x: float(x[0]), reverse=True)

def find_element(text, element):
    """
    Function to extract the relevant information for a given element from the text.
    :param text: Extracted text from the image
    :param element: The element to find (e.g., "item_weight", "height").
    :return: The matched value with units or 'Not Found'.
    """
    # Treat maximum_weight_recommendation as item_weight
    if element == "maximum_weight_recommendation":
        element = "item_weight"

    if element not in patterns:
        return "Invalid element provided"

    # Get the regex pattern for the requested element
    pattern = patterns[element]

    # Search for the pattern in the extracted text
    matches = re.findall(pattern, text, re.IGNORECASE)

    if element == "item_weight" and matches:
        return find_highest_weight(matches)

    if matches:
        # If multiple matches, sort them in descending order
        sorted_matches = sort_matches_by_value(matches)

        # If height is requested, return the largest value
        if element == "height":
            return replace_units_with_full_form(sorted_matches[0])

        # If width is requested and there are multiple matches, return the second largest
        if element == "width" and len(sorted_matches) > 1:
            return replace_units_with_full_form(sorted_matches[1])

        # For wattage, handle special cases like 0.45W vs. 65W
        if element == "wattage":
            # Filter out incorrect wattage matches (like IP65)
            correct_wattage = [m for m in sorted_matches if "W" in m[3] or "watt" in m[3]]
            if correct_wattage:
                return replace_units_with_full_form(correct_wattage[0])
            return replace_units_with_full_form(sorted_matches[0])

        # For other elements or single matches, return the first match
        return replace_units_with_full_form(sorted_matches[0])

    return ""

def main():
    final = []
    # Iterate for each image
    for i in range(25000):
        print(f"\nProcessing Image {i}:")
        img_path = 'image'+str(i)+'.jpg'
        # Ask for the extracted text
        extracted_text = extract_text_from_image(img_path)
        # Ask for the element to find
        element_to_find = e_name[i]

        # Find the element in the text
        result = find_element(extracted_text, element_to_find)
        final.append(result)
    return final

# %%
import pandas as pd

# Call the main function to get predictions
final = main()

# Create an index that matches the length of final
index = list(range(1, len(final) + 1))  # Assuming the index starts from 1

# Ensure that 'index' and 'final' are of the same length
if len(index) == len(final):
    # Create the DataFrame
    data = {
        "index": index,
        "prediction": final,
    }

    df_final = pd.DataFrame(data)
    print(df_final)  # Display the DataFrame
else:
    print("Error: The length of 'index' and 'final' must match.")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Processing Image 16978:
# [2024/09/15 09:12:53] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05361461639404297
# [2024/09/15 09:12:53] ppocr DEBUG: cls num  : 2, elapsed : 0.008414983749389648
# [2024/09/15 09:12:53] ppocr DEBUG: rec_res num  : 2, elapsed : 0.012171030044555664
#
# Processing Image 16979:
# [2024/09/15 09:12:54] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.05703091621398926
# [2024/09/15 09:12:54] ppocr DEBUG: cls num  : 7, elapsed : 0.01736593246459961
# [2024/09/15 09:12:54] ppocr DEBUG: rec_res num  : 7, elapsed : 0.02977275848388672
#
# Processing Image 16980:
# [2024/09/15 09:12:54] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.06421661376953125
# [2024/09/15 09:12:54] ppocr DEBUG: cls num  : 7, elapsed : 0.01976180076599121
# [2024/09/15 09:12:54] ppocr DEBUG: rec_res num  : 7, elapsed : 0.03250288963317871
#
# Processing Image 16981:
# [2024/09/15 09:12:54] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.06169247627258301
# [2024/09/15 09:12:54] ppocr DEBUG: cls num  : 7, elapsed : 0.023670434951782227
# [2024/09/15 09:12:54] ppocr DEBUG: rec_res num  : 7, elapsed : 0.028122663497924805
#
# Processing Image 16982:
# [2024/09/15 09:12:54] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05301070213317871
# [2024/09/15 09:12:54] ppocr DEBUG: cls num  : 2, elapsed : 0.018311262130737305
# [2024/09/15 09:12:54] ppocr DEBUG: rec_res num  : 2, elapsed : 0.013666629791259766
#
# Processing Image 16983:
# [2024/09/15 09:12:54] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0657346248626709
# [2024/09/15 09:12:54] ppocr DEBUG: cls num  : 2, elapsed : 0.017317533493041992
# [2024/09/15 09:12:54] ppocr DEBUG: rec_res num  : 2, elapsed : 0.016286373138427734
#
# Processing Image 16984:
# [2024/09/15 09:12:54] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06827068328857422
# [2024/09/15 09:12:54] ppocr DEBUG: cls num  : 2, elapsed : 0.010796070098876953
# [2024/09/15 09:12:54] ppocr DEBUG: rec_res num  : 2, elapsed : 0.014613628387451172
#
# Processing Image 16985:
# [2024/09/15 09:12:54] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05761075019836426
# [2024/09/15 09:12:54] ppocr DEBUG: cls num  : 2, elapsed : 0.01214146614074707
# [2024/09/15 09:12:54] ppocr DEBUG: rec_res num  : 2, elapsed : 0.015703201293945312
#
# Processing Image 16986:
# [2024/09/15 09:12:54] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06421494483947754
# [2024/09/15 09:12:54] ppocr DEBUG: cls num  : 2, elapsed : 0.01038217544555664
# [2024/09/15 09:12:54] ppocr DEBUG: rec_res num  : 2, elapsed : 0.01080179214477539
#
# Processing Image 16987:
# [2024/09/15 09:12:54] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.059537410736083984
# [2024/09/15 09:12:54] ppocr DEBUG: cls num  : 2, elapsed : 0.008558273315429688
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 2, elapsed : 0.014441251754760742
#
# Processing Image 16988:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.026955842971801758
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 4, elapsed : 0.01021575927734375
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 4, elapsed : 0.01961684226989746
#
# Processing Image 16989:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05029129981994629
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 2, elapsed : 0.0087738037109375
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 2, elapsed : 0.012255668640136719
#
# Processing Image 16990:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.046456098556518555
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 2, elapsed : 0.008520126342773438
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 2, elapsed : 0.01080465316772461
#
# Processing Image 16991:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.025873184204101562
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 5, elapsed : 0.011136531829833984
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 5, elapsed : 0.03271603584289551
#
# Processing Image 16992:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.026270151138305664
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 5, elapsed : 0.010741233825683594
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 5, elapsed : 0.03365635871887207
#
# Processing Image 16993:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.025770902633666992
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 5, elapsed : 0.010993003845214844
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 5, elapsed : 0.03333401679992676
#
# Processing Image 16994:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.029349327087402344
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 9, elapsed : 0.019473791122436523
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 9, elapsed : 0.03400540351867676
#
# Processing Image 16995:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.032990455627441406
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 4, elapsed : 0.013560056686401367
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 4, elapsed : 0.030580520629882812
#
# Processing Image 16996:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.05884861946105957
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 3, elapsed : 0.015475034713745117
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 3, elapsed : 0.017562150955200195
#
# Processing Image 16997:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.07445263862609863
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 3, elapsed : 0.010515213012695312
# [2024/09/15 09:12:55] ppocr DEBUG: rec_res num  : 3, elapsed : 0.012599468231201172
#
# Processing Image 16998:
# [2024/09/15 09:12:55] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.03192472457885742
# [2024/09/15 09:12:55] ppocr DEBUG: cls num  : 17, elapsed : 0.027412891387939453
# [2024/09/15 09:12:56] ppocr DEBUG: rec_res num  : 17, elapsed : 0.10585236549377441
#
# Processing Image 16999:
# [2024/09/15 09:12:56] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.029499292373657227
# [2024/09/15 09:12:56] ppocr DEBUG: cls num  : 8, elapsed : 0.016498565673828125
# [2024/09/15 09:12:56] ppocr DEBUG: rec_res num  : 8, elapsed : 0.028931379318237305
#
# Processing Image 17000:
# [2024/09/15 09:12:56] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.032523393630981445
# [2024/09/15 09:12:56] ppocr DEBUG: cls num  : 1, elapsed : 0.01218867301940918
# [2024/09/15 09:12:56] ppocr DEBUG: rec_res num  : 1, elapsed : 0.011397123336791992
#
# Processing Image 17001:
# [2024/09/15 09:12:56] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.03148508071899414
# [2024/09/15 09:12:56] ppocr DEBUG: cls num  : 8, elapsed : 0.024594545364379883
# [2024/09/15 09:12:56] ppocr DEBUG: rec_res num  : 8, elapsed : 0.03474259376525879
#
# Processing Image 17002:
# [2024/09/15 09:12:56] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06416726112365723
# [2024/09/15 09:12:56] ppocr DEBUG: cls num  : 2, elapsed : 0.009583711624145508
# [2024/09/15 09:12:56] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011404752731323242
#
# Processing Image 17003:
# [2024/09/15 09:12:56] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05170392990112305
# [2024/09/15 09:12:56] ppocr DEBUG: cls num  : 2, elapsed : 0.012758731842041016
# [2024/09/15 09:12:56] ppocr DEBUG: rec_res num  : 2, elapsed : 0.015352725982666016
#
# Processing Image 17004:
# [2024/09/15 09:12:56] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.07213306427001953
# [2024/09/15 09:12:56] ppocr DEBUG: cls num  : 2, elapsed : 0.013271331787109375
# [2024/09/15 09:12:56] ppocr DEBUG: rec_res num  : 2, elapsed : 0.018671035766601562
#
# Processing Image 17005:
# [2024/09/15 09:12:56] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.09026098251342773
# [2024/09/15 09:12:56] ppocr DEBUG: cls num  : 2, elapsed : 0.01265859603881836
# [2024/09/15 09:12:56] ppocr DEBUG: rec_res num  : 2, elapsed : 0.012185811996459961
#
# Processing Image 17006:
# [2024/09/15 09:12:56] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.03700423240661621
# [2024/09/15 09:12:56] ppocr DEBUG: cls num  : 9, elapsed : 0.022076845169067383
# [2024/09/15 09:12:56] ppocr DEBUG: rec_res num  : 9, elapsed : 0.041457414627075195
#
# Processing Image 17007:
# [2024/09/15 09:12:57] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06943726539611816
# [2024/09/15 09:12:57] ppocr DEBUG: cls num  : 2, elapsed : 0.01704549789428711
# [2024/09/15 09:12:57] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0125579833984375
#
# Processing Image 17008:
# [2024/09/15 09:12:57] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06347894668579102
# [2024/09/15 09:12:57] ppocr DEBUG: cls num  : 2, elapsed : 0.009479999542236328
# [2024/09/15 09:12:57] ppocr DEBUG: rec_res num  : 2, elapsed : 0.015951156616210938
#
# Processing Image 17009:
# [2024/09/15 09:12:57] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04802393913269043
# [2024/09/15 09:12:57] ppocr DEBUG: cls num  : 3, elapsed : 0.009292364120483398
# [2024/09/15 09:12:57] ppocr DEBUG: rec_res num  : 3, elapsed : 0.011410951614379883
#
# Processing Image 17010:
# [2024/09/15 09:12:57] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.027833938598632812
# [2024/09/15 09:12:57] ppocr DEBUG: cls num  : 5, elapsed : 0.00962972640991211
# [2024/09/15 09:12:57] ppocr DEBUG: rec_res num  : 5, elapsed : 0.017401933670043945
#
# Processing Image 17011:
# [2024/09/15 09:12:57] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.05948138236999512
# [2024/09/15 09:12:57] ppocr DEBUG: cls num  : 7, elapsed : 0.024972200393676758
# [2024/09/15 09:12:57] ppocr DEBUG: rec_res num  : 7, elapsed : 0.030077695846557617
#
# Processing Image 17012:
# [2024/09/15 09:12:57] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.06631064414978027
# [2024/09/15 09:12:57] ppocr DEBUG: cls num  : 7, elapsed : 0.021351337432861328
# [2024/09/15 09:12:57] ppocr DEBUG: rec_res num  : 7, elapsed : 0.02945733070373535
#
# Processing Image 17013:
# [2024/09/15 09:12:57] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.09438180923461914
# [2024/09/15 09:12:57] ppocr DEBUG: cls num  : 7, elapsed : 0.024550199508666992
# [2024/09/15 09:12:57] ppocr DEBUG: rec_res num  : 7, elapsed : 0.028760910034179688
#
# Processing Image 17014:
# [2024/09/15 09:12:57] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.05735039710998535
# [2024/09/15 09:12:57] ppocr DEBUG: cls num  : 5, elapsed : 0.009942054748535156
# [2024/09/15 09:12:57] ppocr DEBUG: rec_res num  : 5, elapsed : 0.018088340759277344
#
# Processing Image 17015:
# [2024/09/15 09:12:58] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.05988025665283203
# [2024/09/15 09:12:58] ppocr DEBUG: cls num  : 5, elapsed : 0.012664079666137695
# [2024/09/15 09:12:58] ppocr DEBUG: rec_res num  : 5, elapsed : 0.019546985626220703
#
# Processing Image 17016:
# [2024/09/15 09:12:58] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.0356748104095459
# [2024/09/15 09:12:58] ppocr DEBUG: cls num  : 12, elapsed : 0.02458500862121582
# [2024/09/15 09:12:58] ppocr DEBUG: rec_res num  : 12, elapsed : 0.04986882209777832
#
# Processing Image 17017:
# [2024/09/15 09:12:58] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06179523468017578
# [2024/09/15 09:12:58] ppocr DEBUG: cls num  : 2, elapsed : 0.008561849594116211
# [2024/09/15 09:12:58] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011146783828735352
#
# Processing Image 17018:
# [2024/09/15 09:12:58] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.054461002349853516
# [2024/09/15 09:12:58] ppocr DEBUG: cls num  : 2, elapsed : 0.00853872299194336
# [2024/09/15 09:12:58] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011870384216308594
#
# Processing Image 17019:
# [2024/09/15 09:12:58] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.03431272506713867
# [2024/09/15 09:12:58] ppocr DEBUG: cls num  : 11, elapsed : 0.02282571792602539
# [2024/09/15 09:12:58] ppocr DEBUG: rec_res num  : 11, elapsed : 0.04182887077331543
#
# Processing Image 17020:
# [2024/09/15 09:12:58] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.030174970626831055
# [2024/09/15 09:12:58] ppocr DEBUG: cls num  : 9, elapsed : 0.025579452514648438
# [2024/09/15 09:12:58] ppocr DEBUG: rec_res num  : 9, elapsed : 0.05339813232421875
#
# Processing Image 17021:
# [2024/09/15 09:12:58] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.0741419792175293
# [2024/09/15 09:12:58] ppocr DEBUG: cls num  : 4, elapsed : 0.019888639450073242
# [2024/09/15 09:12:58] ppocr DEBUG: rec_res num  : 4, elapsed : 0.0252993106842041
#
# Processing Image 17022:
# [2024/09/15 09:12:58] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.042275428771972656
# [2024/09/15 09:12:58] ppocr DEBUG: cls num  : 7, elapsed : 0.022878646850585938
# [2024/09/15 09:12:58] ppocr DEBUG: rec_res num  : 7, elapsed : 0.03438568115234375
#
# Processing Image 17023:
# [2024/09/15 09:12:58] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.03682136535644531
# [2024/09/15 09:12:58] ppocr DEBUG: cls num  : 4, elapsed : 0.014883041381835938
# [2024/09/15 09:12:58] ppocr DEBUG: rec_res num  : 4, elapsed : 0.022009611129760742
#
# Processing Image 17024:
# [2024/09/15 09:12:59] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.06223130226135254
# [2024/09/15 09:12:59] ppocr DEBUG: cls num  : 3, elapsed : 0.009392738342285156
# [2024/09/15 09:12:59] ppocr DEBUG: rec_res num  : 3, elapsed : 0.012109518051147461
#
# Processing Image 17025:
# [2024/09/15 09:12:59] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.028711557388305664
# [2024/09/15 09:12:59] ppocr DEBUG: cls num  : 8, elapsed : 0.017275094985961914
# [2024/09/15 09:12:59] ppocr DEBUG: rec_res num  : 8, elapsed : 0.029562950134277344
#
# Processing Image 17026:
# [2024/09/15 09:12:59] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.03556704521179199
# [2024/09/15 09:12:59] ppocr DEBUG: cls num  : 12, elapsed : 0.023156166076660156
# [2024/09/15 09:12:59] ppocr DEBUG: rec_res num  : 12, elapsed : 0.05836987495422363
#
# Processing Image 17027:
# [2024/09/15 09:12:59] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.06450676918029785
# [2024/09/15 09:12:59] ppocr DEBUG: cls num  : 6, elapsed : 0.012679338455200195
# [2024/09/15 09:12:59] ppocr DEBUG: rec_res num  : 6, elapsed : 0.02864861488342285
#
# Processing Image 17028:
# [2024/09/15 09:12:59] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.08199381828308105
# [2024/09/15 09:12:59] ppocr DEBUG: cls num  : 6, elapsed : 0.016691923141479492
# [2024/09/15 09:12:59] ppocr DEBUG: rec_res num  : 6, elapsed : 0.028099536895751953
#
# Processing Image 17029:
# [2024/09/15 09:12:59] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.06840229034423828
# [2024/09/15 09:12:59] ppocr DEBUG: cls num  : 6, elapsed : 0.012582063674926758
# [2024/09/15 09:12:59] ppocr DEBUG: rec_res num  : 6, elapsed : 0.027103424072265625
#
# Processing Image 17030:
# [2024/09/15 09:12:59] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.07051753997802734
# [2024/09/15 09:12:59] ppocr DEBUG: cls num  : 3, elapsed : 0.010635137557983398
# [2024/09/15 09:12:59] ppocr DEBUG: rec_res num  : 3, elapsed : 0.012500524520874023
#
# Processing Image 17031:
# [2024/09/15 09:12:59] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.025130271911621094
# [2024/09/15 09:12:59] ppocr DEBUG: cls num  : 1, elapsed : 0.009565114974975586
# [2024/09/15 09:12:59] ppocr DEBUG: rec_res num  : 1, elapsed : 0.01403188705444336
#
# Processing Image 17032:
# [2024/09/15 09:12:59] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.026117801666259766
# [2024/09/15 09:12:59] ppocr DEBUG: cls num  : 1, elapsed : 0.009696722030639648
# [2024/09/15 09:12:59] ppocr DEBUG: rec_res num  : 1, elapsed : 0.011078596115112305
#
# Processing Image 17033:
# [2024/09/15 09:13:00] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.07129120826721191
# [2024/09/15 09:13:00] ppocr DEBUG: cls num  : 2, elapsed : 0.010262012481689453
# [2024/09/15 09:13:00] ppocr DEBUG: rec_res num  : 2, elapsed : 0.015546560287475586
#
# Processing Image 17034:
# [2024/09/15 09:13:00] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.03377103805541992
# [2024/09/15 09:13:00] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2024/09/15 09:13:00] ppocr DEBUG: rec_res num  : 0, elapsed : 1.9073486328125e-06
#
# Processing Image 17035:
# [2024/09/15 09:13:00] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.03585457801818848
# [2024/09/15 09:13:00] ppocr DEBUG: cls num  : 14, elapsed : 0.029805421829223633
# [2024/09/15 09:13:00] ppocr DEBUG: rec_res num  : 14, elapsed : 0.06668305397033691
#
# Processing Image 17036:
# [2024/09/15 09:13:00] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.058804988861083984
# [2024/09/15 09:13:00] ppocr DEBUG: cls num  : 4, elapsed : 0.010071754455566406
# [2024/09/15 09:13:00] ppocr DEBUG: rec_res num  : 4, elapsed : 0.014524459838867188
#
# Processing Image 17037:
# [2024/09/15 09:13:00] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.02788996696472168
# [2024/09/15 09:13:00] ppocr DEBUG: cls num  : 6, elapsed : 0.009774446487426758
# [2024/09/15 09:13:00] ppocr DEBUG: rec_res num  : 6, elapsed : 0.04078245162963867
#
# Processing Image 17038:
# [2024/09/15 09:13:00] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.056581735610961914
# [2024/09/15 09:13:00] ppocr DEBUG: cls num  : 8, elapsed : 0.030225515365600586
# [2024/09/15 09:13:00] ppocr DEBUG: rec_res num  : 8, elapsed : 0.035517215728759766
#
# Processing Image 17039:
# [2024/09/15 09:13:00] ppocr DEBUG: dt_boxes num : 19, elapsed : 0.0473635196685791
# [2024/09/15 09:13:00] ppocr DEBUG: cls num  : 19, elapsed : 0.045270442962646484
# [2024/09/15 09:13:00] ppocr DEBUG: rec_res num  : 19, elapsed : 0.08184027671813965
#
# Processing Image 17040:
# [2024/09/15 09:13:00] ppocr DEBUG: dt_boxes num : 19, elapsed : 0.058562517166137695
# [2024/09/15 09:13:00] ppocr DEBUG: cls num  : 19, elapsed : 0.04251718521118164
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 19, elapsed : 0.0756223201751709
#
# Processing Image 17041:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.02537083625793457
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 5, elapsed : 0.010529756546020508
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 5, elapsed : 0.015401363372802734
#
# Processing Image 17042:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.033829689025878906
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 5, elapsed : 0.011658668518066406
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 5, elapsed : 0.020148038864135742
#
# Processing Image 17043:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.026638507843017578
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 5, elapsed : 0.01185154914855957
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 5, elapsed : 0.017647504806518555
#
# Processing Image 17044:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.03801274299621582
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 14, elapsed : 0.030558109283447266
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 14, elapsed : 0.05984950065612793
#
# Processing Image 17045:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06323385238647461
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 2, elapsed : 0.009159564971923828
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 2, elapsed : 0.010934114456176758
#
# Processing Image 17046:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.059836626052856445
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 2, elapsed : 0.009072542190551758
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 2, elapsed : 0.01139521598815918
#
# Processing Image 17047:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.08084440231323242
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 2, elapsed : 0.012360334396362305
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 2, elapsed : 0.015945911407470703
#
# Processing Image 17048:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.03102707862854004
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 6, elapsed : 0.012506723403930664
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 6, elapsed : 0.01842355728149414
#
# Processing Image 17049:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06575298309326172
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 2, elapsed : 0.009742259979248047
# [2024/09/15 09:13:01] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011794567108154297
#
# Processing Image 17050:
# [2024/09/15 09:13:01] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.02656698226928711
# [2024/09/15 09:13:01] ppocr DEBUG: cls num  : 4, elapsed : 0.010675191879272461
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 4, elapsed : 0.017980098724365234
#
# Processing Image 17051:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.03765416145324707
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 16, elapsed : 0.03146553039550781
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 16, elapsed : 0.06899118423461914
#
# Processing Image 17052:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.0519556999206543
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 7, elapsed : 0.015383481979370117
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 7, elapsed : 0.028740882873535156
#
# Processing Image 17053:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04578447341918945
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 3, elapsed : 0.008874893188476562
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 3, elapsed : 0.012783050537109375
#
# Processing Image 17054:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.040639400482177734
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 4, elapsed : 0.008961677551269531
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 4, elapsed : 0.012903213500976562
#
# Processing Image 17055:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.04366493225097656
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 4, elapsed : 0.008962869644165039
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 4, elapsed : 0.01353144645690918
#
# Processing Image 17056:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0232851505279541
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 1, elapsed : 0.007842540740966797
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 1, elapsed : 0.010128021240234375
#
# Processing Image 17057:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.04427790641784668
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 7, elapsed : 0.02211284637451172
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 7, elapsed : 0.026497364044189453
#
# Processing Image 17058:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.05347776412963867
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 4, elapsed : 0.01317453384399414
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 4, elapsed : 0.013724327087402344
#
# Processing Image 17059:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.02582716941833496
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 11, elapsed : 0.014691829681396484
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 11, elapsed : 0.038602352142333984
#
# Processing Image 17060:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.025777339935302734
# [2024/09/15 09:13:02] ppocr DEBUG: cls num  : 8, elapsed : 0.014679431915283203
# [2024/09/15 09:13:02] ppocr DEBUG: rec_res num  : 8, elapsed : 0.024176359176635742
#
# Processing Image 17061:
# [2024/09/15 09:13:02] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.025313138961791992
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 7, elapsed : 0.015440702438354492
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 7, elapsed : 0.03683209419250488
#
# Processing Image 17062:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.02366805076599121
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 14, elapsed : 0.021631956100463867
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 14, elapsed : 0.04484415054321289
#
# Processing Image 17063:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.029070377349853516
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 17, elapsed : 0.021446704864501953
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 17, elapsed : 0.052190542221069336
#
# Processing Image 17064:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.026761531829833984
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 5, elapsed : 0.010372161865234375
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 5, elapsed : 0.013077735900878906
#
# Processing Image 17065:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04224061965942383
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 3, elapsed : 0.009098291397094727
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 3, elapsed : 0.011282682418823242
#
# Processing Image 17066:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.020246028900146484
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 12, elapsed : 0.017073392868041992
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 12, elapsed : 0.057317256927490234
#
# Processing Image 17067:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.026741743087768555
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 12, elapsed : 0.01586747169494629
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 12, elapsed : 0.05698800086975098
#
# Processing Image 17068:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.02716231346130371
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 12, elapsed : 0.02393174171447754
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 12, elapsed : 0.057802677154541016
#
# Processing Image 17069:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.05611371994018555
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 1, elapsed : 0.008659124374389648
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 1, elapsed : 0.010311126708984375
#
# Processing Image 17070:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.04112887382507324
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 1, elapsed : 0.010249853134155273
# [2024/09/15 09:13:03] ppocr DEBUG: rec_res num  : 1, elapsed : 0.009429931640625
#
# Processing Image 17071:
# [2024/09/15 09:13:03] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.03985452651977539
# [2024/09/15 09:13:03] ppocr DEBUG: cls num  : 1, elapsed : 0.007688999176025391
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 1, elapsed : 0.012000083923339844
#
# Processing Image 17072:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.019394636154174805
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 1, elapsed : 0.00899958610534668
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 1, elapsed : 0.010656356811523438
#
# Processing Image 17073:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.022328853607177734
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 4, elapsed : 0.009824752807617188
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 4, elapsed : 0.011133909225463867
#
# Processing Image 17074:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.043996572494506836
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 7, elapsed : 0.016707420349121094
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 7, elapsed : 0.03146696090698242
#
# Processing Image 17075:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.020672321319580078
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 8, elapsed : 0.016925573348999023
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 8, elapsed : 0.023120641708374023
#
# Processing Image 17076:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.024974822998046875
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 6, elapsed : 0.008847713470458984
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 6, elapsed : 0.017864704132080078
#
# Processing Image 17077:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.044229984283447266
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 3, elapsed : 0.008955955505371094
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 3, elapsed : 0.012634515762329102
#
# Processing Image 17078:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.03985190391540527
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 3, elapsed : 0.008704900741577148
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 3, elapsed : 0.009617090225219727
#
# Processing Image 17079:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.032614946365356445
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 14, elapsed : 0.021280288696289062
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 14, elapsed : 0.03571462631225586
#
# Processing Image 17080:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.032196760177612305
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 23, elapsed : 0.035529136657714844
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 23, elapsed : 0.06751847267150879
#
# Processing Image 17081:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.02982187271118164
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 4, elapsed : 0.011677265167236328
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 4, elapsed : 0.01267862319946289
#
# Processing Image 17082:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.026331424713134766
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 4, elapsed : 0.01078176498413086
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 4, elapsed : 0.012894153594970703
#
# Processing Image 17083:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.02786850929260254
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 4, elapsed : 0.009777545928955078
# [2024/09/15 09:13:04] ppocr DEBUG: rec_res num  : 4, elapsed : 0.01052713394165039
#
# Processing Image 17084:
# [2024/09/15 09:13:04] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.03527116775512695
# [2024/09/15 09:13:04] ppocr DEBUG: cls num  : 3, elapsed : 0.009302616119384766
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 3, elapsed : 0.010889530181884766
#
# Processing Image 17085:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.027480125427246094
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 16, elapsed : 0.02013993263244629
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 16, elapsed : 0.03791689872741699
#
# Processing Image 17086:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.02225208282470703
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 7, elapsed : 0.016294002532958984
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 7, elapsed : 0.022238492965698242
#
# Processing Image 17087:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.021120071411132812
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 1, elapsed : 0.008259773254394531
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 1, elapsed : 0.010669469833374023
#
# Processing Image 17088:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04591202735900879
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 3, elapsed : 0.010476350784301758
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 3, elapsed : 0.010192155838012695
#
# Processing Image 17089:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04674553871154785
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 2, elapsed : 0.00909113883972168
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011116504669189453
#
# Processing Image 17090:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.027842283248901367
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 11, elapsed : 0.015761375427246094
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 11, elapsed : 0.029416561126708984
#
# Processing Image 17091:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.025089502334594727
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 11, elapsed : 0.016249895095825195
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 11, elapsed : 0.030068397521972656
#
# Processing Image 17092:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.027920961380004883
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 11, elapsed : 0.02173757553100586
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 11, elapsed : 0.05222320556640625
#
# Processing Image 17093:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.03654336929321289
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 23, elapsed : 0.040903329849243164
# [2024/09/15 09:13:05] ppocr DEBUG: rec_res num  : 23, elapsed : 0.0793905258178711
#
# Processing Image 17094:
# [2024/09/15 09:13:05] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.032851457595825195
# [2024/09/15 09:13:05] ppocr DEBUG: cls num  : 23, elapsed : 0.027722597122192383
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 23, elapsed : 0.07626080513000488
#
# Processing Image 17095:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.027312755584716797
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 23, elapsed : 0.027237892150878906
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 23, elapsed : 0.07297682762145996
#
# Processing Image 17096:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.036780357360839844
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 2, elapsed : 0.008563518524169922
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011371850967407227
#
# Processing Image 17097:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03719449043273926
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 2, elapsed : 0.008843421936035156
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 2, elapsed : 0.010793447494506836
#
# Processing Image 17098:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.038498878479003906
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 2, elapsed : 0.009379386901855469
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 2, elapsed : 0.014184236526489258
#
# Processing Image 17099:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.05547475814819336
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 4, elapsed : 0.00946354866027832
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 4, elapsed : 0.012641429901123047
#
# Processing Image 17100:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.036054134368896484
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 3, elapsed : 0.009955167770385742
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 3, elapsed : 0.011055231094360352
#
# Processing Image 17101:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.03477025032043457
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 3, elapsed : 0.010695934295654297
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 3, elapsed : 0.01106572151184082
#
# Processing Image 17102:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.05610370635986328
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 5, elapsed : 0.011549234390258789
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 5, elapsed : 0.014791727066040039
#
# Processing Image 17103:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.05402231216430664
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 5, elapsed : 0.013424396514892578
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 5, elapsed : 0.01180720329284668
#
# Processing Image 17104:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.034391164779663086
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 4, elapsed : 0.009108781814575195
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 4, elapsed : 0.011914253234863281
#
# Processing Image 17105:
# [2024/09/15 09:13:06] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.034631967544555664
# [2024/09/15 09:13:06] ppocr DEBUG: cls num  : 4, elapsed : 0.009685754776000977
# [2024/09/15 09:13:06] ppocr DEBUG: rec_res num  : 4, elapsed : 0.012359380722045898
#
# Processing Image 17106:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.043958187103271484
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 1, elapsed : 0.009501934051513672
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 1, elapsed : 0.012113332748413086
#
# Processing Image 17107:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.04303860664367676
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 1, elapsed : 0.009820222854614258
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 1, elapsed : 0.011070013046264648
#
# Processing Image 17108:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.03803610801696777
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 1, elapsed : 0.01103067398071289
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 1, elapsed : 0.011695146560668945
#
# Processing Image 17109:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.03077077865600586
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 25, elapsed : 0.032196998596191406
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 25, elapsed : 0.06173276901245117
#
# Processing Image 17110:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0393221378326416
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 2, elapsed : 0.00867462158203125
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 2, elapsed : 0.012111902236938477
#
# Processing Image 17111:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04868459701538086
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 2, elapsed : 0.00826263427734375
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 2, elapsed : 0.010228633880615234
#
# Processing Image 17112:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.03763151168823242
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 1, elapsed : 0.009871721267700195
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 1, elapsed : 0.010887622833251953
#
# Processing Image 17113:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.043677330017089844
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 1, elapsed : 0.013145923614501953
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 1, elapsed : 0.010443925857543945
#
# Processing Image 17114:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.024079322814941406
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 4, elapsed : 0.010195493698120117
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 4, elapsed : 0.032691001892089844
#
# Processing Image 17115:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.02768540382385254
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 4, elapsed : 0.012072324752807617
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 4, elapsed : 0.03177762031555176
#
# Processing Image 17116:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.040279388427734375
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 5, elapsed : 0.00960850715637207
# [2024/09/15 09:13:07] ppocr DEBUG: rec_res num  : 5, elapsed : 0.01485133171081543
#
# Processing Image 17117:
# [2024/09/15 09:13:07] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.02068948745727539
# [2024/09/15 09:13:07] ppocr DEBUG: cls num  : 11, elapsed : 0.015631675720214844
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 11, elapsed : 0.03823447227478027
#
# Processing Image 17118:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.022541284561157227
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 7, elapsed : 0.015065908432006836
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 7, elapsed : 0.036776065826416016
#
# Processing Image 17119:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.025532007217407227
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 8, elapsed : 0.013198375701904297
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 8, elapsed : 0.025916576385498047
#
# Processing Image 17120:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.02279973030090332
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 8, elapsed : 0.013926982879638672
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 8, elapsed : 0.024149656295776367
#
# Processing Image 17121:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.022986173629760742
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 8, elapsed : 0.014028310775756836
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 8, elapsed : 0.023537874221801758
#
# Processing Image 17122:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03703117370605469
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 2, elapsed : 0.010068893432617188
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011152982711791992
#
# Processing Image 17123:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03978133201599121
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 2, elapsed : 0.009191036224365234
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.015323162078857422
#
# Processing Image 17124:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04034423828125
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 2, elapsed : 0.009771108627319336
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.010030984878540039
#
# Processing Image 17125:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04321718215942383
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 3, elapsed : 0.009530782699584961
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 3, elapsed : 0.016743898391723633
#
# Processing Image 17126:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.03289651870727539
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 7, elapsed : 0.01805591583251953
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 7, elapsed : 0.024449586868286133
#
# Processing Image 17127:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.0512239933013916
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 3, elapsed : 0.009979248046875
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 3, elapsed : 0.010361433029174805
#
# Processing Image 17128:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.02126145362854004
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 7, elapsed : 0.020314455032348633
# [2024/09/15 09:13:08] ppocr DEBUG: rec_res num  : 7, elapsed : 0.02653336524963379
#
# Processing Image 17129:
# [2024/09/15 09:13:08] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.021458148956298828
# [2024/09/15 09:13:08] ppocr DEBUG: cls num  : 4, elapsed : 0.008885860443115234
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 4, elapsed : 0.02604818344116211
#
# Processing Image 17130:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.016040563583374023
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 5, elapsed : 0.008059978485107422
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 5, elapsed : 0.021785974502563477
#
# Processing Image 17131:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04280686378479004
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 3, elapsed : 0.009294748306274414
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 3, elapsed : 0.013342142105102539
#
# Processing Image 17132:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04169321060180664
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 3, elapsed : 0.009626388549804688
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 3, elapsed : 0.012673377990722656
#
# Processing Image 17133:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04161334037780762
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 3, elapsed : 0.009829282760620117
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 3, elapsed : 0.011382818222045898
#
# Processing Image 17134:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.04327869415283203
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 9, elapsed : 0.01617598533630371
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 9, elapsed : 0.02190423011779785
#
# Processing Image 17135:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.04175877571105957
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 9, elapsed : 0.016155481338500977
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 9, elapsed : 0.02263617515563965
#
# Processing Image 17136:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.03772377967834473
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 3, elapsed : 0.010199308395385742
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 3, elapsed : 0.011275291442871094
#
# Processing Image 17137:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.026732444763183594
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 3, elapsed : 0.00939798355102539
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 3, elapsed : 0.014337301254272461
#
# Processing Image 17138:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.028254270553588867
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 6, elapsed : 0.015350580215454102
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 6, elapsed : 0.01508021354675293
#
# Processing Image 17139:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.02932906150817871
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 6, elapsed : 0.017292022705078125
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 6, elapsed : 0.01748180389404297
#
# Processing Image 17140:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.05257749557495117
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 5, elapsed : 0.011516809463500977
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 5, elapsed : 0.01414799690246582
#
# Processing Image 17141:
# [2024/09/15 09:13:09] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.046764373779296875
# [2024/09/15 09:13:09] ppocr DEBUG: cls num  : 5, elapsed : 0.011007308959960938
# [2024/09/15 09:13:09] ppocr DEBUG: rec_res num  : 5, elapsed : 0.013705253601074219
#
# Processing Image 17142:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.04326963424682617
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 5, elapsed : 0.009839773178100586
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 5, elapsed : 0.015160083770751953
#
# Processing Image 17143:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02052450180053711
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 2, elapsed : 0.00859975814819336
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.014891624450683594
#
# Processing Image 17144:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.041723012924194336
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 4, elapsed : 0.008587837219238281
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 4, elapsed : 0.012189865112304688
#
# Processing Image 17145:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.0258486270904541
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 8, elapsed : 0.014024019241333008
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 8, elapsed : 0.02360224723815918
#
# Processing Image 17146:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.02577996253967285
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 11, elapsed : 0.015687942504882812
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 11, elapsed : 0.038313865661621094
#
# Processing Image 17147:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.049295663833618164
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 3, elapsed : 0.009012222290039062
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 3, elapsed : 0.012680292129516602
#
# Processing Image 17148:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04596447944641113
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 3, elapsed : 0.009818553924560547
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 3, elapsed : 0.016237735748291016
#
# Processing Image 17149:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04596686363220215
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 2, elapsed : 0.010312318801879883
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011085987091064453
#
# Processing Image 17150:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05433845520019531
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 2, elapsed : 0.012494325637817383
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011278152465820312
#
# Processing Image 17151:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04063534736633301
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 2, elapsed : 0.012149572372436523
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011433601379394531
#
# Processing Image 17152:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.057483673095703125
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 2, elapsed : 0.009362459182739258
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.010914325714111328
#
# Processing Image 17153:
# [2024/09/15 09:13:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04085135459899902
# [2024/09/15 09:13:10] ppocr DEBUG: cls num  : 2, elapsed : 0.010256767272949219
# [2024/09/15 09:13:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011795759201049805
#
# Processing Image 17154:
# ...
#
# Processing Image 17918:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.0406794548034668
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 4, elapsed : 0.009198665618896484
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 4, elapsed : 0.01349496841430664
#
# Processing Image 17919:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.0395205020904541
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 4, elapsed : 0.01070713996887207
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 4, elapsed : 0.012890815734863281
#
# Processing Image 17920:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0431215763092041
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 2, elapsed : 0.01118612289428711
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 2, elapsed : 0.013878345489501953
#
# Processing Image 17921:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.06011033058166504
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 3, elapsed : 0.010545730590820312
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 3, elapsed : 0.012570858001708984
#
# Processing Image 17922:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.02683115005493164
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 5, elapsed : 0.011277914047241211
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 5, elapsed : 0.024387121200561523
#
# Processing Image 17923:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.029436111450195312
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 6, elapsed : 0.010803699493408203
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 6, elapsed : 0.02163076400756836
#
# Processing Image 17924:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.03160595893859863
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 6, elapsed : 0.009802103042602539
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 6, elapsed : 0.02190089225769043
#
# Processing Image 17925:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.034770965576171875
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 6, elapsed : 0.010117053985595703
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 6, elapsed : 0.021510601043701172
#
# Processing Image 17926:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06432271003723145
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 2, elapsed : 0.010528564453125
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 2, elapsed : 0.012529850006103516
#
# Processing Image 17927:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0787496566772461
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 2, elapsed : 0.008737802505493164
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 2, elapsed : 0.013666391372680664
#
# Processing Image 17928:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.028977155685424805
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 5, elapsed : 0.012764215469360352
# [2024/09/15 09:14:30] ppocr DEBUG: rec_res num  : 5, elapsed : 0.01579737663269043
#
# Processing Image 17929:
# [2024/09/15 09:14:30] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.03059077262878418
# [2024/09/15 09:14:30] ppocr DEBUG: cls num  : 3, elapsed : 0.01017904281616211
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 3, elapsed : 0.029831409454345703
#
# Processing Image 17930:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.026373624801635742
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 3, elapsed : 0.009345293045043945
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 3, elapsed : 0.030139684677124023
#
# Processing Image 17931:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.026150226593017578
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 3, elapsed : 0.009448766708374023
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 3, elapsed : 0.03149890899658203
#
# Processing Image 17932:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.03406047821044922
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 14, elapsed : 0.027819395065307617
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 14, elapsed : 0.043692588806152344
#
# Processing Image 17933:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.031636714935302734
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 11, elapsed : 0.017748594284057617
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 11, elapsed : 0.03845024108886719
#
# Processing Image 17934:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.031104087829589844
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 11, elapsed : 0.01703667640686035
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 11, elapsed : 0.03934025764465332
#
# Processing Image 17935:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.02542853355407715
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 10, elapsed : 0.01745152473449707
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 10, elapsed : 0.037522077560424805
#
# Processing Image 17936:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.0361175537109375
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 21, elapsed : 0.04140758514404297
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 21, elapsed : 0.08879518508911133
#
# Processing Image 17937:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.0597076416015625
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 3, elapsed : 0.01036834716796875
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 3, elapsed : 0.0136566162109375
#
# Processing Image 17938:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.0317685604095459
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 4, elapsed : 0.010424613952636719
# [2024/09/15 09:14:31] ppocr DEBUG: rec_res num  : 4, elapsed : 0.011980295181274414
#
# Processing Image 17939:
# [2024/09/15 09:14:31] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.036566734313964844
# [2024/09/15 09:14:31] ppocr DEBUG: cls num  : 10, elapsed : 0.02117323875427246
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 10, elapsed : 0.0450897216796875
#
# Processing Image 17940:
# [2024/09/15 09:14:32] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.0674583911895752
# [2024/09/15 09:14:32] ppocr DEBUG: cls num  : 7, elapsed : 0.02884960174560547
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 7, elapsed : 0.03135538101196289
#
# Processing Image 17941:
# [2024/09/15 09:14:32] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.058977603912353516
# [2024/09/15 09:14:32] ppocr DEBUG: cls num  : 3, elapsed : 0.008847951889038086
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 3, elapsed : 0.010723114013671875
#
# Processing Image 17942:
# [2024/09/15 09:14:32] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0516352653503418
# [2024/09/15 09:14:32] ppocr DEBUG: cls num  : 2, elapsed : 0.008661508560180664
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 2, elapsed : 0.01078939437866211
#
# Processing Image 17943:
# [2024/09/15 09:14:32] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05659127235412598
# [2024/09/15 09:14:32] ppocr DEBUG: cls num  : 2, elapsed : 0.008203268051147461
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 2, elapsed : 0.01070404052734375
#
# Processing Image 17944:
# [2024/09/15 09:14:32] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.05447793006896973
# [2024/09/15 09:14:32] ppocr DEBUG: cls num  : 5, elapsed : 0.011321783065795898
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 5, elapsed : 0.015194892883300781
#
# Processing Image 17945:
# [2024/09/15 09:14:32] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.02463221549987793
# [2024/09/15 09:14:32] ppocr DEBUG: cls num  : 2, elapsed : 0.008159637451171875
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 2, elapsed : 0.014506816864013672
#
# Processing Image 17946:
# [2024/09/15 09:14:32] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.03633522987365723
# [2024/09/15 09:14:32] ppocr DEBUG: cls num  : 23, elapsed : 0.0459749698638916
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 23, elapsed : 0.08175158500671387
#
# Processing Image 17947:
# [2024/09/15 09:14:32] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0527191162109375
# [2024/09/15 09:14:32] ppocr DEBUG: cls num  : 2, elapsed : 0.008576631546020508
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011428117752075195
#
# Processing Image 17948:
# [2024/09/15 09:14:32] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.05691266059875488
# [2024/09/15 09:14:32] ppocr DEBUG: cls num  : 3, elapsed : 0.010489463806152344
# [2024/09/15 09:14:32] ppocr DEBUG: rec_res num  : 3, elapsed : 0.015172243118286133
#
# Processing Image 17949:
# [2024/09/15 09:14:33] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.06164240837097168
# [2024/09/15 09:14:33] ppocr DEBUG: cls num  : 3, elapsed : 0.014384031295776367
# [2024/09/15 09:14:33] ppocr DEBUG: rec_res num  : 3, elapsed : 0.01308894157409668
#
# Processing Image 17950:
# [2024/09/15 09:14:33] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.030351877212524414
# [2024/09/15 09:14:33] ppocr DEBUG: cls num  : 5, elapsed : 0.014876604080200195
# [2024/09/15 09:14:33] ppocr DEBUG: rec_res num  : 5, elapsed : 0.01761627197265625
#
# Processing Image 17951:
# [2024/09/15 09:14:33] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.03334212303161621
# [2024/09/15 09:14:33] ppocr DEBUG: cls num  : 17, elapsed : 0.027288198471069336
# [2024/09/15 09:14:33] ppocr DEBUG: rec_res num  : 17, elapsed : 0.06381893157958984
#
# Processing Image 17952:
# [2024/09/15 09:14:33] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.027019977569580078
# [2024/09/15 09:14:33] ppocr DEBUG: cls num  : 6, elapsed : 0.009760618209838867
# [2024/09/15 09:14:33] ppocr DEBUG: rec_res num  : 6, elapsed : 0.021076440811157227
#
# Processing Image 17953:
# [2024/09/15 09:14:33] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06190657615661621
# [2024/09/15 09:14:33] ppocr DEBUG: cls num  : 2, elapsed : 0.008580446243286133
# [2024/09/15 09:14:33] ppocr DEBUG: rec_res num  : 2, elapsed : 0.010802507400512695
#
# Processing Image 17954:
# [2024/09/15 09:14:33] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06545400619506836
# [2024/09/15 09:14:33] ppocr DEBUG: cls num  : 2, elapsed : 0.008165597915649414
# [2024/09/15 09:14:33] ppocr DEBUG: rec_res num  : 2, elapsed : 0.011101484298706055
#
# Processing Image 17955:
# [2024/09/15 09:14:33] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.06081557273864746
# [2024/09/15 09:14:33] ppocr DEBUG: cls num  : 5, elapsed : 0.011946439743041992
# [2024/09/15 09:14:33] ppocr DEBUG: rec_res num  : 5, elapsed : 0.03676128387451172
#
# Processing Image 17956:
# [2024/09/15 09:14:33] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.04293704032897949
# [2024/09/15 09:14:33] ppocr DEBUG: cls num  : 3, elapsed : 0.017295360565185547
# [2024/09/15 09:14:33] ppocr DEBUG: rec_res num  : 3, elapsed : 0.019884586334228516
#
# Processing Image 17957:
# [2024/09/15 09:14:33] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.04497885704040527
# [2024/09/15 09:14:33] ppocr DEBUG: cls num  : 11, elapsed : 0.02264094352722168
# [2024/09/15 09:14:33] ppocr DEBUG: rec_res num  : 11, elapsed : 0.03606843948364258
#
# Processing Image 17958:
# [2024/09/15 09:14:34] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.05895805358886719
# [2024/09/15 09:14:34] ppocr DEBUG: cls num  : 6, elapsed : 0.010737419128417969
# [2024/09/15 09:14:34] ppocr DEBUG: rec_res num  : 6, elapsed : 0.02207803726196289
#
# Processing Image 17959:
# [2024/09/15 09:14:34] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06949186325073242
# [2024/09/15 09:14:34] ppocr DEBUG: cls num  : 2, elapsed : 0.011367559432983398
# [2024/09/15 09:14:34] ppocr DEBUG: rec_res num  : 2, elapsed : 0.013419628143310547
#
# Processing Image 17960:
# [2024/09/15 09:14:34] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06542682647705078
# [2024/09/15 09:14:34] ppocr DEBUG: cls num  : 2, elapsed : 0.011449813842773438
# [2024/09/15 09:14:34] ppocr DEBUG: rec_res num  : 2, elapsed : 0.010241508483886719
#
# Processing Image 17961:
# [2024/09/15 09:14:34] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.05986976623535156
# [2024/09/15 09:14:34] ppocr DEBUG: cls num  : 6, elapsed : 0.013565540313720703
# [2024/09/15 09:14:34] ppocr DEBUG: rec_res num  : 6, elapsed : 0.020171642303466797
#
# Processing Image 17962:
# [2024/09/15 09:14:34] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.05316901206970215
# [2024/09/15 09:14:34] ppocr DEBUG: cls num  : 6, elapsed : 0.010946273803710938
# [2024/09/15 09:14:34] ppocr DEBUG: rec_res num  : 6, elapsed : 0.02336430549621582
#
# Processing Image 17963:
# [2024/09/15 09:14:34] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.06094980239868164
# [2024/09/15 09:14:34] ppocr DEBUG: cls num  : 3, elapsed : 0.010164976119995117
# [2024/09/15 09:14:34] ppocr DEBUG: rec_res num  : 3, elapsed : 0.011332511901855469
#
# Processing Image 17964:
# [2024/09/15 09:14:34] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.06286787986755371
# [2024/09/15 09:14:34] ppocr DEBUG: cls num  : 3, elapsed : 0.01809215545654297
# [2024/09/15 09:14:34] ppocr DEBUG: rec_res num  : 3, elapsed : 0.018947362899780273
#
# Processing Image 17965:
# [2024/09/15 09:14:34] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.054631710052490234
# [2024/09/15 09:14:34] ppocr DEBUG: cls num  : 3, elapsed : 0.012168645858764648
# [2024/09/15 09:14:34] ppocr DEBUG: rec_res num  : 3, elapsed : 0.012973308563232422
#
# Processing Image 17966:
# [2024/09/15 09:14:34] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.06876397132873535
# [2024/09/15 09:14:34] ppocr DEBUG: cls num  : 6, elapsed : 0.018381595611572266
# [2024/09/15 09:14:35] ppocr DEBUG: rec_res num  : 6, elapsed : 0.021619081497192383
#
# Processing Image 17967:
# [2024/09/15 09:14:35] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.06778454780578613
# [2024/09/15 09:14:35] ppocr DEBUG: cls num  : 6, elapsed : 0.012295722961425781
# [2024/09/15 09:14:35] ppocr DEBUG: rec_res num  : 6, elapsed : 0.01965475082397461
#
# Processing Image 17968:
# [2024/09/15 09:14:35] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.07140517234802246
# [2024/09/15 09:14:35] ppocr DEBUG: cls num  : 4, elapsed : 0.011455059051513672
# [2024/09/15 09:14:35] ppocr DEBUG: rec_res num  : 4, elapsed : 0.014048099517822266
#
# Processing Image 17969:
# [2024/09/15 09:14:35] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.030515193939208984
# [2024/09/15 09:14:35] ppocr DEBUG: cls num  : 10, elapsed : 0.020815372467041016
# [2024/09/15 09:14:35] ppocr DEBUG: rec_res num  : 10, elapsed : 0.04369688034057617
#
# Processing Image 17970:
# [2024/09/15 09:14:35] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.060991764068603516
# [2024/09/15 09:14:35] ppocr DEBUG: cls num  : 3, elapsed : 0.010093927383422852
# [2024/09/15 09:14:35] ppocr DEBUG: rec_res num  : 3, elapsed : 0.015047311782836914
#
# Processing Image 17971:
# [2024/09/15 09:14:35] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.03401923179626465
# [2024/09/15 09:14:35] ppocr DEBUG: cls num  : 7, elapsed : 0.029911041259765625
# [2024/09/15 09:14:35] ppocr DEBUG: rec_res num  : 7, elapsed : 0.033971309661865234
#
# Processing Image 17972:
# [2024/09/15 09:14:35] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.032233238220214844
# [2024/09/15 09:14:35] ppocr DEBUG: cls num  : 7, elapsed : 0.020224809646606445
# [2024/09/15 09:14:35] ppocr DEBUG: rec_res num  : 7, elapsed : 0.03541970252990723
#
# Processing Image 17973:
# [2024/09/15 09:14:35] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.05477714538574219
# [2024/09/15 09:14:35] ppocr DEBUG: cls num  : 3, elapsed : 0.016739845275878906
# [2024/09/15 09:14:35] ppocr DEBUG: rec_res num  : 3, elapsed : 0.021880626678466797
#
# Processing Image 17974:
# [2024/09/15 09:14:35] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.053102970123291016
# [2024/09/15 09:14:35] ppocr DEBUG: cls num  : 15, elapsed : 0.03307008743286133
# [2024/09/15 09:14:35] ppocr DEBUG: rec_res num  : 15, elapsed : 0.05307483673095703
#        index                prediction
# 0          1         199.39 centimetre
# 1          2                78.74 inch
# 2          3          200.0 centimetre
# 3          4          200.0 centimetre
# 4          5           90.0 centimetre
# ...      ...                       ...
# 17970  17971               170.0 meter
# 17971  17972                 12.0 volt
# 17972  17973                 Not Found
# 17973  17974                 57.5 inch
# 17974  17975  Invalid element provided
#
# [17975 rows x 2 columns]

# %%
df_final.to_csv('test_out.csv')

# %%
from google.colab import files
files.download('test_out.csv')
